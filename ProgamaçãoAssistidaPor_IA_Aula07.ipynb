# %% [markdown]
# <a href="https://colab.research.google.com/github/SaintGabs/Engenharia_de_Prompt_e_Aplicacoes_em_IA/blob/main/Progama%C3%A7%C3%A3oAssistidaPorIa_Aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 07 - A.I Projeto
# **Nome**: Gabriel Dos Santos Paz \
# **Disciplina**: Enganharia de prompt e aplicação em IA
