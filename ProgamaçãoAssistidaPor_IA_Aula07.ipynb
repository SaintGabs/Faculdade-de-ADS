# %% [markdown]
# <a href="https://colab.research.google.com/github/SaintGabs/Engenharia_de_Prompt_e_Aplicacoes_em_IA/blob/main/Progama%C3%A7%C3%A3oAssistidaPor_IA_Aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 07 - Projeto assistido por IA
# **Nome**: Gabriel Dos Santos Paz \
# **Disciplina**: Enganharia de prompt e aplicação em IA

# %% [markdown]
# ###Exemplos

# %%
#Soma de listas
numeros = [1, 2, 3, 4, 5] # Example: defining the list 'numeros'
soma = sum(numeros)
print(soma)
# Out:
# 15

# %%
import math
def primo(n):
  if n <= 1:
    return False
  for i in range(2, int(math.sqrt(n)) + 1):
    if n % i == 0:
      return False
  return True

# %%
#Imversão de String
def inverte_texto(texto):
  return texto[::-1]

# %% [markdown]
# ###Mini Projeto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# tipos de ia, a partir dos fundamento de ia conceitua llm, entender oque é engenharia de prompt com termômetro , token, e COT, construir prompt eficaz e testar prompt simples e prompt eficaz resumo unidade 1 fundamentos de ia generativa e prompt
#
#
# csv, json,yaml, xml
